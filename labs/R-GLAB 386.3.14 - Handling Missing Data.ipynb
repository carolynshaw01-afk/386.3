# %% [markdown]
# # **R-Guided Lab 386.3.14 - Handling Missing Data**

# %% [markdown]
# ## **Lab Overview**
#
# <font color="red">**This is a graded lab and is mandatory. The instructor will go through it in class. Learners must complete and submit the lab within two days.**</font>
#
#
# ==>  Missing data is a common problem in real-world datasets.
# ==>  It can occur for various reasons, such as:
#                                                     ==> data entry errors,
#                                                     ==> sensor malfunctions,                or
#                                                     ==> simply incomplete data collection.
#
# ==> In this lab, we will demonstrate how to handle:
#         missing data (mostly in the form NaN value) in Pandas,
# ==> we will utilize the:
#                             **DataFrame.dropna()**
#                             **DataFrame.fillna()** and
#                             **DataFrame.replace()** functions.
#
# ## **Lab Objective:**
# By the end of this lab, learners will be able to:
#
# - Describe the need for Handling Missing Data:
# - Explore the Role of np.nan in Representing Missing Data:
# - Utilize the **df.dropna(), DataFrame.fillna()**and **DataFrame.replace()** functions to handle missing data.
# - Identify and understand the implications of missing data in datasets.
#
# ## **Introduction**
#
# Missing data is a common problem in real-world datasets. It can occur for various reasons, such as data entry errors, sensor malfunctions, or simply incomplete data collection.
# In this lab, we will demonstrate the techniques for handling missing data using the Pandas library in Python.
# We will focus on identifying, understanding, and applying different strategies for dealing with missing values.
# By the end of this lab, you will be equipped with the knowledge and tools to effectively manage missing data in your own datasets.
#
# ---
#
# # **Begin:**

# %% [markdown]
# **Example 1: Dropping or Cleaning the Missing Data Using df.dropna() method.**
#
# **This following example initializes a pandas DataFrame with a dataset representing information about employees.
# **NaN               It then demonstrates how to handle missing data by dropping rows containing NaN (Not a Number) values using the **dropna()** function.
# **dropna()          The **dropna()** function drops all the rows with missing values.
#
#
#
# **Note:**The `np.nan` values in the dataset are representative of missing or undefined data, and np refers to the NumPy library.
# **Make sure to import NumPy (import numpy as np) before using *np.nan*.

# %%
# np.nan represents a missing value in the dataset

# Create the DataFrame with Name, Age, Weight, and Salary columns

# Check the original data before removing missing values

# dropna() removes rows that contain a missing value

# Carolyn Talk:  "Pandas, if a row has a missing value, drop that whole row."

# ****Dropping isn't automatially the right answer.  My lab itself warns that dropna() can cause information loss.  So the larger lesson is inspect the missing data first, then decide how to 
# handle it.****

import numpy as np
import pandas as pd
# np.nan represents a missing value in the dataset
# Initializing the nested list with Data set
employee_list = [['James', 36, 75, 5428000],
                 ['Villers', 38, 74, 3428000],
                 ['VKole', 31, 70, 8428000],
                 ['Smith', 34, 80, 4428000],
                 ['Gayle', 40, 100, 4528000],
                 ['Adam', 40, np.nan, 4528000],
                 ['Rooter', 33, 72, 7028000],
                 ['Peterson', 42, 85, 2528000],
                 ['lynda', 42, 85, np.nan],
                 [np.nan, 42, 85, np.nan],
                 ['Jenny', np.nan, 100, 25632],
                 ['Kenn', np.nan, 110, 25632],
                 ['Aly', np.nan, 90, 25582],
                 ['John', 41, 85, 1528000]]

# creating a pandas dataframe
# Create the DataFrame with Name, Age, Weight, and Salary columns
df = pd.DataFrame(employee_list, columns=['Name', 'Age', 'Weight', 'Salary'])

# Check the original data before removing missing values
print(df)
print('---- after dropping or cleaning the missing data ---')
df = df.dropna()
print(df)

# print(df)
# "Shaw me my DataFrame BEFORE I change anthing."
# print('---- after dropping or cleaning the missing data ----')
# This one doesn't do anything to the data at all.  It's just a label so when you look at the output, you know:  "Okay, everything below this line is AFTER the cleaning."
# Then the actual work happens:  df = df.dropna()
# Pandas, remove the rows containing missing values and save the cleaned result back into df."
# And finally:
# print(df)"
# "Now show me the DataFrame AFTER I chaned it."
# Question?:  Why do we need three print() functions?
# You do NOT need three print() functions to use dropna().
# This alone perms the cleaning:
# df = .dropna()

# Think:  
# TASK:  Remove rows with missing data.
# TOOL:  dropna()
# PRINT:  Only shows me what's happening.
# dropona() is the worker.  print() is just showing you the worker's work.
# Out:
#         Name   Age  Weight     Salary
# 0      James  36.0    75.0  5428000.0
# 1    Villers  38.0    74.0  3428000.0
# 2      VKole  31.0    70.0  8428000.0
# 3      Smith  34.0    80.0  4428000.0
# 4      Gayle  40.0   100.0  4528000.0
# 5       Adam  40.0     NaN  4528000.0
# 6     Rooter  33.0    72.0  7028000.0
# 7   Peterson  42.0    85.0  2528000.0
# 8      lynda  42.0    85.0        NaN
# 9        NaN  42.0    85.0        NaN
# 10     Jenny   NaN   100.0    25632.0
# 11      Kenn   NaN   110.0    25632.0
# 12       Aly   NaN    90.0    25582.0
# 13      John  41.0    85.0  1528000.0
# ---- after dropping or cleaning the missing data ---
#         Name   Age  Weight     Salary
# 0      James  36.0    75.0  5428000.0
# 1    Villers  38.0    74.0  3428000.0
# 2      VKole  31.0    70.0  8428000.0
# 3      Smith  34.0    80.0  4428000.0
# 4      Gayle  40.0   100.0  4528000.0
# 6     Rooter  33.0    72.0  7028000.0
# 7   Peterson  42.0    85.0  2528000.0
# ...

# %% [markdown]
# ***********************************************************************************************************************
# What I learned: dropna() removes the entire row when that row contains a missing value.
# Dropping data is not automatically the right choice because useful information in the rest of that row may also be lost.
# I should inspect the missing data before deciding how to handle it.
# Example:  Adam:  has a Name, Age, and Salary; only his Weight is missing.  dropna() says, essentially, "one thing is missing, throw away the entire Adam record."

# %% [markdown]
# Like many other approaches, dropna() also has some pros and cons.
#
# **Pros**
#
# - Straightforward and simple to use.
# - Beneficial when missing values have no importance.
#
# **Cons**
# - Using this approach can lead to information loss, which can introduce bias to the final dataset.
# - This is not appropriate when the data is not missing completely at random.
# - Data set with a large proportion of missing value can be significantly decreased, which can impact the result of all statistical analysis on that data set.

# %% [markdown]
# **Example 2: Filling Missing Data Using df.fillna() method**
#
# Pandas has several options for filling or replacing missing values with other values. One of the most convenient methods is the **.fillna()** method; you can use it to replace missing values with:
#
# - Specified values.
#
# - The values above the missing value.
#
# - The values below the missing value.
#
# **Syntax:**
#
#  `DataFrame.fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None, **kwargs)`
#
# **Parameters:**
# - **value:** static, dictionary, array, series, or dataframe to fill instead of NaN.
# - **method:** Method is used if the user does not pass any value. Pandas has different methods like bfill(), backfill(), or ffill(), which fills the place with value in the Forward index or Previous/Back, respectively.
# - **axis:** axis takes int or string value for rows/columns. Input can be 0 or 1 for Integer and ‘index’ or ‘columns’ for String.
# inplace: a boolean, which makes the changes in the data frame itself if True.
# - **limit:** an integer value, which specifies the maximum number of consecutive forward/backward NaN value fills.
# - **downcast**: takes a dict, which specifies what dtype to downcast to which one such as float64 to int64.
# - **kwargs:** any other keyword arguments.

# %% [markdown]
# Consider the following Data frame.

# %%
import pandas as pd
import numpy as np
# Initializing the nested list with Data set
employee_list = [['James', 36, 75, 5428000],
               ['Villers', 38, 74, 3428000],
               ['VKole', 31, 70, 8428000],
               ['Smith', 34, 80, 4428000],
               ['Gayle', 40, 100, 4528000],
               ['Adam', 40, np.nan, 4528000],
               ['Rooter', 33, 72, 7028000],
               ['Peterson', 42, 85, 2528000],
               ['lynda', 42, 85, np.nan],
               [np.nan, 42, 85, np.nan],
               ['John', 41, 85, 1528000],]

# Creating a pandas dataframe
df = pd.DataFrame(employee_list, columns=['Name', 'Age', 'Weight', 'Salary'])

print(df)
# Out:
#         Name  Age  Weight     Salary
# 0      James   36    75.0  5428000.0
# 1    Villers   38    74.0  3428000.0
# 2      VKole   31    70.0  8428000.0
# 3      Smith   34    80.0  4428000.0
# 4      Gayle   40   100.0  4528000.0
# 5       Adam   40     NaN  4528000.0
# 6     Rooter   33    72.0  7028000.0
# 7   Peterson   42    85.0  2528000.0
# 8      lynda   42    85.0        NaN
# 9        NaN   42    85.0        NaN
# 10      John   41    85.0  1528000.0

# %% [markdown]
# # **Example 2.1: fillna() on all columns**

# %%
# Carolyn's Self-Talk:
# Now I  can move to Example 2:  fillna(), where instead of throwing the row away, I am going to learn how to fill the hole.  That is a very important contrast.
# fillna() on all columns
# df.isnull().com()
# "Pandas, check each column and tell me how many values are missing."
# And the output tells me:

print("--------------- Before Cleaning NaN Values --------------")
print(df)

# 🔹 Count missing values per column
print("\n--------------- Count of Missing Values --------------")
print(df.isnull().sum())

# 🔹 Fill missing values
print("\n--------------- After Filling NaN Values --------------")
print(df.fillna('None'))
# Out:
# --------------- Before Cleaning NaN Values --------------
#         Name  Age  Weight     Salary
# 0      James   36    75.0  5428000.0
# 1    Villers   38    74.0  3428000.0
# 2      VKole   31    70.0  8428000.0
# 3      Smith   34    80.0  4428000.0
# 4      Gayle   40   100.0  4528000.0
# 5       Adam   40     NaN  4528000.0
# 6     Rooter   33    72.0  7028000.0
# 7   Peterson   42    85.0  2528000.0
# 8      lynda   42    85.0        NaN
# 9        NaN   42    85.0        NaN
# 10      John   41    85.0  1528000.0
#
# --------------- Count of Missing Values --------------
# Name      1
# Age       0
# Weight    1
# Salary    2
# dtype: int64
#
# --------------- After Filling NaN Values --------------
#         Name  Age Weight     Salary
# 0      James   36   75.0  5428000.0
# 1    Villers   38   74.0  3428000.0
# 2      VKole   31   70.0  8428000.0
# 3      Smith   34   80.0  4428000.0
# 4      Gayle   40  100.0  4528000.0
# 5       Adam   40   None  4528000.0
# ...

# %% [markdown]
# # What I learned:
# # fillna() keeps the rows and fills the missing values instead of deleting the rows.
# # Here, every NaN is replaced with the string 'None'.
# # Important: 'None' is text here because it is inside quotes.

# %% [markdown]
# ## **Example 2.2:  Fill same value on multiple columns from NaN values**
#
# The below example updates columns 'Weight' and 'Age' with 'pending' for NaN values:

# %%
''' import pandas as pd
import numpy as np
employee_list = [['James', 36, 75, 5428000],
               ['Villers', 38, 74, 3428000],
               ['VKole', 31, 70, 8428000],
               ['Smith', 34, 80, 4428000],
               ['Gayle', 40, 100, 4528000],
               ['Adam', 40, np.nan, 4528000],
               ['Rooter', 33, 72, 7028000],
               ['Peterson', 42, 85, 2528000],
               ['lynda', 42, 85, np.nan],
               [np.nan, 42, 85, np.nan],
               ['Jenny', np.nan, 100, 25632],
               ['Kenn', np.nan, 110, 25632],
                ['Aly', np.nan, 90, 25582],
               ['John', 41, 85, 1528000],]
'''

print("---------------After Cleaning NaN values from multiple columns--------------")
df =df[['Weight','Age']].fillna('pending')
# Carolyn's Self-Talk:
# Read from the right side of the = because that's the work we're asking Python to do:
# df ==> my DataFrameWeight', 'Age']]
# ==> "From my DataFrame, give me these TWO columns:  Weight and Age."
# Now why two sets of brackets?  [[']]
# [['Weight', 'Age']]
# 
#
# Inner brackets ['Weight', 'Age'] = a LIST of the column names I want.
# Outer brackets [ ] = SELECT those columns from the DataFrame.
#
# So df[['Weight', 'Age']] means:
# "From my DataFrame, give me the Weight and Age columns."
#
# The dot . means: "Now do something to what I just selected."
#
# .fillna('pending') means:
# "In those selected columns, wherever a value is missing, fill it with 'pending'."
#
# df = means:
# "Save the finished result back into df."
# df = means: "Save the finished result back into df."
# Result: df now contains only the Weight and Age columns.
print(df)
# Out:
# ---------------After Cleaning NaN values from multiple columns--------------
#      Weight  Age
# 0      75.0   36
# 1      74.0   38
# 2      70.0   31
# 3      80.0   34
# 4     100.0   40
# 5   pending   40
# 6      72.0   33
# 7      85.0   42
# 8      85.0   42
# 9      85.0   42
# 10     85.0   41

# %% [markdown]
# ##**Example 2.3:  Fill different value for each column**
# Fill different value for each column from NaN values
# Now, let’s see how to fill different values for each column. The below example updates column:
#
# - ‘Name’ with ‘verification pending’,
#
# - ‘Weight’ with ‘pending’,
#
# - ‘Age’ with ‘unknown’
#
# - ‘Salary’ with ‘0.0’ for NaN values.

# %%
# Carolyn's Self-Talk:
# fillna() fills missing values instead of deleting rows.
# { } creates a dictionary of replacement rules.
# Dictionary = KEY : VALUE
# Column name = KEY | Replacement = VALUE
#
# 'Weight': 'Pending'  -> Weight gets Pending
# 'Age': 'Unknown'     -> Age gets Unknown
# 'Salary': '0.0'      -> Salary gets 0.0
# 'Name': 'Verification pending' -> Name gets Verification pending
#
# df2 = means save the filled result into a NEW variable called df2.
#
# Carolyn Talk:
# "Pandas, each column has its OWN rule for what to put in the missing spots."
import pandas as pd
import numpy as np
employee_list = [['James', 36, 75, 5428000],
               ['Villers', 38, 74, 3428000],
               ['VKole', 31, 70, 8428000],
               ['Smith', 34, 80, 4428000],
               ['Gayle', 40, 100, 4528000],
               ['Adam', 40, np.nan, 4528000],
               ['Rooter', 33, 72, 7028000],
               ['Peterson', 42, 85, 2528000],
               ['lynda', 42, 85, np.nan],
               [np.nan, 42, 85, np.nan],
               ['Jenny', np.nan, 100, 25632],
               ['Kenn', np.nan, 110, 25632],
                ['Aly', np.nan, 90, 25582],
               ['John', 41, 85, 1528000],]

# creating a pandas dataframe
df = pd.DataFrame(employee_list, columns=['Name', 'Age', 'Weight', 'Salary'])
print("---------------Before Cleaning NaN values--------------")
print(df)

print("-----after Cleaning NaN values from multiple columns--------------")

df2 = df.fillna(value={'Weight':'Pending','Age':"Unknown", 'Salary': "0.0", 'Name': "Verification pending"})
# fillna() can use a dictionary to give each column a different replacement value.
# { } = dictionary; each column is a KEY and its replacement is the VALUE.
# Carolyn Talk: "Each column gets its own rule for filling missing values."
print(df2)
# Out:
# ---------------Before Cleaning NaN values--------------
#         Name   Age  Weight     Salary
# 0      James  36.0    75.0  5428000.0
# 1    Villers  38.0    74.0  3428000.0
# 2      VKole  31.0    70.0  8428000.0
# 3      Smith  34.0    80.0  4428000.0
# 4      Gayle  40.0   100.0  4528000.0
# 5       Adam  40.0     NaN  4528000.0
# 6     Rooter  33.0    72.0  7028000.0
# 7   Peterson  42.0    85.0  2528000.0
# 8      lynda  42.0    85.0        NaN
# 9        NaN  42.0    85.0        NaN
# 10     Jenny   NaN   100.0    25632.0
# 11      Kenn   NaN   110.0    25632.0
# 12       Aly   NaN    90.0    25582.0
# 13      John  41.0    85.0  1528000.0
# -----after Cleaning NaN values from multiple columns--------------
#                     Name      Age   Weight     Salary
# 0                  James     36.0     75.0  5428000.0
# 1                Villers     38.0     74.0  3428000.0
# 2                  VKole     31.0     70.0  8428000.0
# ...

# %% [markdown]
# # **Pandas Replace NaN with Blank/Empty String**
#
# By using replace() or fillna() methods, you can replace NaN values with a Blank/Empty string in Pandas DataFrame.
#
# Now, let’s create a DataFrame with a few rows and columns, and execute some examples and validate the results. Our DataFrame contains column names Courses, Fee, Duration and Discount.

# %%
# Carolyn's Self-Talk:
# Creates a new DataFrame called df using the technologies dictionary.
# The DataFrame has Courses, Fee, Duration, and Discount columns.
# np.nan shows where values are missing.
import pandas as pd
import numpy as np
technologies = {
    'Courses':["Spark",np.nan,"Hadoop","Python","pandas",np.nan,"Java"],
    'Fee' :[20000,25000, np.nan,22000,24000,np.nan,22000],
    'Duration':[np.nan,'40days','35days', np.nan,'60days','50days','55days'],
    'Discount':[1000,np.nan,1500,np.nan,2500,2100,np.nan]
              }
df = pd.DataFrame(technologies)
print(df)
# Out:
#   Courses      Fee Duration  Discount
# 0   Spark  20000.0      NaN    1000.0
# 1     NaN  25000.0   40days       NaN
# 2  Hadoop      NaN   35days    1500.0
# 3  Python  22000.0      NaN       NaN
# 4  pandas  24000.0   60days    2500.0
# 5     NaN      NaN   50days    2100.0
# 6    Java  22000.0   55days       NaN

# %% [markdown]
# **Example 3: Convert NaN to Empty String in Pandas**
#
# Use **df.replace(np.nan,'',regex=True)** method to replace all NaN values to an empty string in the Pandas DataFrame column.

# %%
import pandas as pd
import numpy as np
technologies = {
    'Courses':["Spark",np.nan,"Hadoop","Python","pandas",np.nan,"Java"],
    'Fee' :[20000,25000, np.nan,22000,24000,np.nan,22000],
    'Duration':[np.nan,'40days','35days', np.nan,'60days','50days','55days'],
    'Discount':[1000,np.nan,1500,np.nan,2500,2100,np.nan]
              }
df = pd.DataFrame(technologies)
df2 = df.replace(np.nan, '', regex=True)
# Carolyns Self-Talk
# “Pandas, in df, replace the NaN values with an empty string, and save the result as df2.”
# '  '    ===> Those are two quotation marks with NOTHING between them.  That means empty string — basically, make that spot appear blank.
print(df2)
# Out:
#   Courses      Fee Duration Discount
# 0   Spark  20000.0            1000.0
# 1          25000.0   40days
# 2  Hadoop            35days   1500.0
# 3  Python  22000.0
# 4  pandas  24000.0   60days   2500.0
# 5                    50days   2100.0
# 6    Java  22000.0   55days

# %% [markdown]
# # What I learned:
# # replace() can replace NaN with another value.
# # '' = an empty string, so the missing value appears blank.
# # Carolyn Talk: "Find the NaN values and replace them with a blank."

# %% [markdown]
# **Example 4: Multiple Columns Replace Empty String**
#
# In order to replace NaN values with Blank strings on multiple columns or all columns from a list, use **df[['Courses','Fee']] = df[['Courses','Fee']].fillna('')**. This replaces NaN values on Courses and Fee columns.

# %%
import pandas as pd
import numpy as np
technologies = {
    'Courses':["Spark",np.nan,"Hadoop","Python","pandas",np.nan,"Java"],
    'Fee' :[20000,25000, np.nan,22000,24000,np.nan,22000],
    'Duration':[np.nan,'40days','35days', np.nan,'60days','50days','55days'],
    'Discount':[1000,np.nan,1500,np.nan,2500,2100,np.nan]
              }
df = pd.DataFrame(technologies)

# Using multiple columns
df2 = df[['Courses','Fee' ]] = df[['Courses','Fee' ]].fillna('PENDING')
# Carolyn's Self-Talk:
# “Give me the Courses and Fee columns. Wherever either one has NaN, fill that hole with 'PENDING'.”
# Fee is normally numbers, but now one of its values is the word PENDING.
print(df2)
# Out:
#    Courses      Fee
# 0    Spark  20000.0
# 1  PENDING  25000.0
# 2   Hadoop  PENDING
# 3   Python  22000.0
# 4   pandas  24000.0
# 5  PENDING  PENDING
# 6     Java  22000.0

# %% [markdown]
# **Example 5: fillna() with inplace=True**
#
# Notice that the above output after applying fillna() function returns a new DataFrame. In order to update the current/referring DataFrame in place, use df.fillna('',inplace=True). When using this, the fillna() method returns the None type.

# %%
#fillna() with inplace=True
import pandas as pd
import numpy as np

# initializing the nested list with Data set and NaN values
technologies = {
    'Courses':["Spark",np.nan,"Hadoop","Python","pandas",np.nan,"Java"],
    'Fee' :[20000,25000, np.nan,22000,24000,np.nan,22000],
    'Duration':[np.nan,'40days','35days', np.nan,'60days','50days','55days'],
    'Discount':[1000,np.nan,1500,np.nan,2500,2100,np.nan]
              }
df = pd.DataFrame(technologies)
# Using pandas replace nan with null
# Allow the DataFrame columns to hold text such as an empty string
df = df.astype(object)
df2 = df.fillna('', inplace=True)
print(df2)
# My pandas version would not put '' into float64 columns.
# astype(object) allows the columns to hold text.
# inplace=True changes df directly, so df2 returns None.
# Out:
#   Courses      Fee Duration Discount
# 0   Spark  20000.0            1000.0
# 1          25000.0   40days
# 2  Hadoop            35days   1500.0
# 3  Python  22000.0
# 4  pandas  24000.0   60days   2500.0
# 5                    50days   2100.0
# 6    Java  22000.0   55days

# %% [markdown]
# **Example 6: Handling Missing Data from CSV file**
#
# In this example, you will practice working with missing data using a dummy employee dataset.
#
# [Click here to download the employee dataset (employee.csv)]((employee.csv)](https://drive.google.com/file/d/14RV1xKIRzWS166LtGqnPC1Wg7eTlI_y1/view))
#
# As learned in the previous examples, the **fillna()** function can be used to handle NaN (missing) values. The dataset (CSV file) contains some missing values, and you will use the **fillna()** function to replace them.

# %%
import pandas as pd
df = pd.read_csv('../data/employee.csv', dtype={'Name':'string' })


print('============Before Handling missing values=====')
print(df)


print('===========After Handling missing values using fillna()=====')
df2 = df.fillna(value={'Name':'Verification Pending','Age':"Unknown", 'Weight': "pending", 'Salary': 0.0})
print(df2)
# Out:
# ============Before Handling missing values=====
#         Name   Age  Weight     Salary
# 0      James  36.0    75.0  5428000.0
# 1    Villers  38.0    74.0  3428000.0
# 2      VKole  31.0    70.0  8428000.0
# 3      Smith  34.0    80.0  4428000.0
# 4      Gayle  40.0   100.0  4528000.0
# 5       Adam  40.0     NaN  4528000.0
# 6     Rooter  33.0    72.0  7028000.0
# 7   Peterson  42.0    85.0  2528000.0
# 8      lynda  42.0    85.0        NaN
# 9       <NA>  42.0    85.0        NaN
# 10     Jenny   NaN   100.0    25632.0
# 11      Kenn   NaN   110.0    25632.0
# 12       Aly   NaN    90.0    25582.0
# 13      John  41.0    85.0  1528000.0
# 14       Ali  26.0    69.0        NaN
# ===========After Handling missing values using fillna()=====
#                     Name      Age   Weight     Salary
# 0                  James     36.0     75.0  5428000.0
# 1                Villers     38.0     74.0  3428000.0
# 2                  VKole     31.0     70.0  8428000.0
# ...

# %% [markdown]
# ##**Submission Instructions**
# - Submit your completed lab using the Start Assignment button on the assignment page in Canvas.
# - Your submission can be include:
#   - if you are using notebook then, all tasks should be written and submitted in a single notebook file, for example: (**your_name_labname.ipynb**).
#   - if you are using python script file, all tasks should be written and submitted in a single python script file for example: **(your_name_labname.py)**.
# - Add appropriate comments and any additional instructions if required.
